# %%
# Install necessary libraries
# %pip install "pybamm[plot,cite]" -q

import pybamm
import matplotlib.pyplot as plt

# Define the battery model
model = pybamm.lithium_ion.DFN(
    {
        "SEI": "solvent-diffusion limited",
        "SEI porosity change": "true",
        "lithium plating": "partially reversible",
        "lithium plating porosity change": "true",  # alias for "SEI porosity change"
        "particle mechanics": ("swelling and cracking", "swelling only"),
        "SEI on cracks": "true",
        "loss of active material": "stress-driven",
        "calculate discharge energy": "true",  # for compatibility with older PyBaMM versions
    }
)

# Set the model parameters
param = pybamm.ParameterValues("OKane2022")
var_pts = {
    "x_n": 5,  # Negative electrode
    "x_s": 5,  # Separator
    "x_p": 5,  # Positive electrode
    "r_n": 30,  # Negative electrode particle
    "r_p": 30,  # Positive electrode particle
}

# Set the maximum number of cycles
max_cycles = 100  # You can increase this to 2000, but the computation will be large
cycle_numbers = list(range(1, max_cycles + 1))  # k = 1, ..., max_cycles
remaining_capacity_values = []  # Store remaining capacity

# Simulate with increasing cycle numbers step by step
for k in cycle_numbers:
    print(f"Calculating cycle {k} ...")  # Show current progress

    # Define the experiment protocol
    exp_k = pybamm.Experiment(
        [
            "Hold at 4.2 V until C/100 (5 minute period)",
            "Rest for 4 hours (5 minute period)",
            "Discharge at 0.1C until 2.5 V (5 minute period)",  # Initial capacity check
            "Charge at 0.3C until 4.2 V (5 minute period)",
            "Hold at 4.2 V until C/100 (5 minute period)",
        ]
        + [
            (
                "Discharge at 1C until 2.5 V",  # Aging cycle
                "Charge at 2C until 4.2 V (5 minute period)",
                "Hold at 4.2 V until C/100 (5 minute period)",
            )
        ]
        * k
        + ["Discharge at 0.1C until 2.5 V (5 minute period)"],  # Final capacity check
    )

    # Run the simulation
    sim_k = pybamm.Simulation(model, parameter_values=param, experiment=exp_k, var_pts=var_pts)
    sol_k = sim_k.solve()

    # Extract the LLI loss (in A.h) and calculate Remaining Capacity (%)
    Q_LLI_final_k = sol_k["Total lithium lost [mol]"].entries[-1] * 96485.3 / 3600  # Convert units
    remaining_capacity_k = (5 - Q_LLI_final_k) / 5 * 100  # Calculate remaining capacity percentage
    remaining_capacity_values.append(remaining_capacity_k)  # Store data

# Plot Remaining Capacity (%) vs. Cycle Number (k)
plt.figure(figsize=(8, 6))
plt.plot(cycle_numbers, remaining_capacity_values, label="Remaining Capacity (%)", color="blue", linewidth=2)
plt.xlabel("Number of cycles (k)")
plt.ylabel("Remaining Capacity (%)")
plt.title("Remaining Capacity vs. Cycle Number")
plt.legend()
plt.grid(True)
plt.ylim(0, 100)  # Limit y-axis range to 0% - 100%
plt.show()
print(f"At k=100, the remaining capacity is: {remaining_capacity_values[-1]:.2f}%")
# Out:
# Note: you may need to restart the kernel to use updated packages.
# 正在计算循环 1 ...
# At t = 429.689 and h = 1.24737e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 189.689 and h = 9.66951e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# 正在计算循环 2 ...
# At t = 429.689 and h = 1.24737e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 189.689 and h = 9.66951e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 428.881 and h = 9.84615e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 188.881 and h = 1.53332e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# 正在计算循环 3 ...
# At t = 429.689 and h = 1.24737e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 189.689 and h = 9.66951e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 428.881 and h = 9.84615e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 188.881 and h = 1.53332e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 428.316 and h = 7.14908e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 188.316 and h = 8.72162e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# 正在计算循环 4 ...
# res failed: KeyboardInterrupt
# At t = 202.842, the residual function failed unrecoverably.
# At t = 367.071 and h = 3.6965e-10, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 189.689 and h = 9.19902e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 428.881 and h = 2.75838e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 188.881 and h = 1.09944e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 428.316 and h = 6.72023e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 188.316 and h = 7.06382e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 96.582 and h = 6.84029e-10, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 427.783 and h = 9.80238e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 187.783 and h = 1.12392e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# 正在计算循环 5 ...
# At t = 429.689 and h = 1.24737e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 189.689 and h = 9.66951e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 428.881 and h = 9.84615e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 188.881 and h = 1.53332e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 428.316 and h = 7.14908e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 188.316 and h = 8.72162e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 324.035 and h = 2.6291e-10, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 187.783 and h = 1.0086e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 427.276 and h = 8.52486e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 187.276 and h = 1.07352e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# 正在计算循环 6 ...
# At t = 429.689 and h = 1.24737e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 189.689 and h = 9.66951e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 428.881 and h = 9.84615e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 188.881 and h = 1.53332e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 428.316 and h = 7.14908e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 188.316 and h = 8.72162e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 324.035 and h = 2.6291e-10, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 187.783 and h = 1.0086e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 427.276 and h = 8.52486e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 187.276 and h = 1.07352e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 426.791 and h = 2.71877e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 186.791 and h = 8.33308e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# 正在计算循环 7 ...
# At t = 429.689 and h = 1.24737e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 189.689 and h = 9.66951e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 428.881 and h = 9.84615e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 188.881 and h = 1.53332e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# res failed: KeyboardInterrupt
# At t = 164.336, the residual function failed unrecoverably.
# At t = 428.316 and h = 8.10814e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 188.316 and h = 1.20057e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 318.939 and h = 3.93261e-10, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 187.783 and h = 9.60421e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 427.276 and h = 8.42385e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 187.276 and h = 9.90215e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 426.791 and h = 4.54187e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 186.791 and h = 2.00131e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 426.323 and h = 8.93732e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 186.323 and h = 6.77766e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# 正在计算循环 8 ...
# At t = 429.689 and h = 1.24737e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 189.689 and h = 9.66951e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 428.881 and h = 9.84615e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 188.881 and h = 1.53332e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 428.316 and h = 7.14908e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 188.316 and h = 8.72162e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 324.035 and h = 2.6291e-10, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 187.783 and h = 1.0086e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 427.276 and h = 8.52486e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 187.276 and h = 1.07352e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 426.791 and h = 2.71877e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 186.791 and h = 8.33308e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 426.324 and h = 6.40938e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 186.324 and h = 6.2971e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 425.872 and h = 5.22656e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 185.871 and h = 8.74472e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# 正在计算循环 9 ...
# At t = 429.689 and h = 1.24737e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 189.689 and h = 9.66951e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 428.881 and h = 9.84615e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 188.881 and h = 1.53332e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 428.316 and h = 7.14908e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 188.316 and h = 8.72162e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 324.035 and h = 2.6291e-10, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 187.783 and h = 1.0086e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 427.276 and h = 8.52486e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 187.276 and h = 1.07352e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 426.791 and h = 2.71877e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 186.791 and h = 8.33308e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 426.324 and h = 6.40938e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 186.324 and h = 6.2971e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 425.872 and h = 5.22656e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 185.871 and h = 8.74472e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 425.433 and h = 6.45642e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 185.432 and h = 1.24738e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# 正在计算循环 10 ...
# At t = 429.689 and h = 1.24737e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 189.689 and h = 9.66951e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 428.881 and h = 9.84615e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 188.881 and h = 1.53332e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 428.316 and h = 7.14908e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 188.316 and h = 8.72162e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 324.035 and h = 2.6291e-10, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 187.783 and h = 1.0086e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 427.276 and h = 8.52486e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 187.276 and h = 1.07352e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 426.791 and h = 2.71877e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 186.791 and h = 8.33308e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 426.324 and h = 6.40938e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 186.324 and h = 6.2971e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 425.872 and h = 5.22656e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 185.871 and h = 8.74472e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 425.433 and h = 6.45642e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 185.432 and h = 1.24738e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 425.005 and h = 2.44231e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 185 and h = 1.52451e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# 正在计算循环 11 ...
# res failed: KeyboardInterrupt
# At t = 2.64779, the residual function failed unrecoverably.
# At t = 429.689 and h = 5.39933e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 189.689 and h = 1.16831e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 348.258 and h = 2.51622e-10, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 188.881 and h = 9.35676e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 428.316 and h = 2.72378e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 188.316 and h = 1.30024e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 427.783 and h = 9.31757e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 187.783 and h = 4.0087e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 427.276 and h = 6.81767e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 187.276 and h = 5.12965e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 426.791 and h = 3.08296e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 186.791 and h = 1.46171e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 426.324 and h = 6.24904e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 186.324 and h = 1.05007e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 425.872 and h = 5.85768e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 185.872 and h = 1.00552e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 425.432 and h = 3.57257e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 185.432 and h = 1.92203e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 425.005 and h = 2.26224e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 185.005 and h = 5.60743e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 424.587 and h = 1.06935e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 184.587 and h = 1.07225e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# 正在计算循环 12 ...
# At t = 429.689 and h = 1.24737e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 189.689 and h = 9.66951e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 428.881 and h = 9.84615e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 188.881 and h = 1.53332e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 428.316 and h = 7.14908e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 188.316 and h = 8.72162e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 324.035 and h = 2.6291e-10, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 187.783 and h = 1.0086e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 427.276 and h = 8.52486e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 187.276 and h = 1.07352e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 426.791 and h = 2.71877e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 186.791 and h = 8.33308e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 426.324 and h = 6.40938e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 186.324 and h = 6.2971e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 425.872 and h = 5.22656e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 185.871 and h = 8.74472e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 425.433 and h = 6.45642e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 185.432 and h = 1.24738e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 425.005 and h = 2.44231e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 185 and h = 1.52451e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 424.587 and h = 1.17106e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 184.587 and h = 1.33604e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 117.659 and h = 3.47241e-10, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 424.178 and h = 9.33117e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 136.209 and h = 8.35194e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# 正在计算循环 13 ...
# At t = 429.689 and h = 1.24737e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 189.689 and h = 9.66951e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 428.881 and h = 9.84615e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 188.881 and h = 1.53332e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 428.316 and h = 7.14908e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 188.316 and h = 8.72162e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 324.035 and h = 2.6291e-10, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 187.783 and h = 1.0086e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 427.276 and h = 8.52486e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 187.276 and h = 1.07352e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 426.791 and h = 2.71877e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 186.791 and h = 8.33308e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 426.324 and h = 6.40938e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 186.324 and h = 6.2971e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 425.872 and h = 5.22656e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 185.871 and h = 8.74472e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 425.433 and h = 6.45642e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 185.432 and h = 1.24738e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 425.005 and h = 2.44231e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 185 and h = 1.52451e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 424.587 and h = 1.17106e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 184.587 and h = 1.33604e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 117.659 and h = 3.47241e-10, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 424.178 and h = 9.33117e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 136.209 and h = 8.35194e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 423.776 and h = 3.22015e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 183.776 and h = 1.66384e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# 正在计算循环 14 ...
# At t = 429.689 and h = 1.24737e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 189.689 and h = 9.66951e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 428.881 and h = 9.84615e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 188.881 and h = 1.53332e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 428.316 and h = 7.14908e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 188.316 and h = 8.72162e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 324.035 and h = 2.6291e-10, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 187.783 and h = 1.0086e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 427.276 and h = 8.52486e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 187.276 and h = 1.07352e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 426.791 and h = 2.71877e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 186.791 and h = 8.33308e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 426.324 and h = 6.40938e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 186.324 and h = 6.2971e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 425.872 and h = 5.22656e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 185.871 and h = 8.74472e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 425.433 and h = 6.45642e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 185.432 and h = 1.24738e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 425.005 and h = 2.44231e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 185 and h = 1.52451e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 424.587 and h = 1.17106e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 184.587 and h = 1.33604e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 117.659 and h = 3.47241e-10, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 424.178 and h = 9.33117e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 136.209 and h = 8.35194e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 423.776 and h = 3.22015e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 183.776 and h = 1.66384e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 366.89 and h = 6.96452e-10, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 183.381 and h = 7.50928e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# 正在计算循环 15 ...
# At t = 429.689 and h = 1.24737e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 189.689 and h = 9.66951e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 428.881 and h = 9.84615e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 188.881 and h = 1.53332e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 428.316 and h = 7.14908e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 188.316 and h = 8.72162e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 324.035 and h = 2.6291e-10, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 187.783 and h = 1.0086e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 427.276 and h = 8.52486e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 187.276 and h = 1.07352e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 426.791 and h = 2.71877e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 186.791 and h = 8.33308e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 426.324 and h = 6.40938e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 186.324 and h = 6.2971e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 425.872 and h = 5.22656e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 185.871 and h = 8.74472e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 425.433 and h = 6.45642e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 185.432 and h = 1.24738e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 425.005 and h = 2.44231e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 185 and h = 1.52451e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 424.587 and h = 1.17106e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 184.587 and h = 1.33604e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 117.659 and h = 3.47241e-10, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 424.178 and h = 9.33117e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 136.209 and h = 8.35194e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 423.776 and h = 3.22015e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 183.776 and h = 1.66384e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 366.89 and h = 6.96452e-10, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 183.381 and h = 7.50928e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 422.992 and h = 4.10533e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 182.992 and h = 5.41809e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# 正在计算循环 16 ...
# At t = 429.689 and h = 1.24737e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 189.689 and h = 9.66951e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 428.881 and h = 9.84615e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 188.881 and h = 1.53332e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 428.316 and h = 7.14908e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 188.316 and h = 8.72162e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 324.035 and h = 2.6291e-10, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 187.783 and h = 1.0086e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 427.276 and h = 8.52486e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 187.276 and h = 1.07352e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 426.791 and h = 2.71877e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 186.791 and h = 8.33308e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 426.324 and h = 6.40938e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 186.324 and h = 6.2971e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 425.872 and h = 5.22656e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 185.871 and h = 8.74472e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 425.433 and h = 6.45642e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 185.432 and h = 1.24738e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 425.005 and h = 2.44231e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 185 and h = 1.52451e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 424.587 and h = 1.17106e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 184.587 and h = 1.33604e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 117.659 and h = 3.47241e-10, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 424.178 and h = 9.33117e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 136.209 and h = 8.35194e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 423.776 and h = 3.22015e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 183.776 and h = 1.66384e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 366.89 and h = 6.96452e-10, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 183.381 and h = 7.50928e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 422.992 and h = 4.10533e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 182.992 and h = 5.41809e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 422.608 and h = 1.23314e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 182.608 and h = 1.1319e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# 正在计算循环 17 ...
# At t = 429.689 and h = 1.24737e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 189.689 and h = 9.66951e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 428.881 and h = 9.84615e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 188.881 and h = 1.53332e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 428.316 and h = 7.14908e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 188.316 and h = 8.72162e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 324.035 and h = 2.6291e-10, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 187.783 and h = 1.0086e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 427.276 and h = 8.52486e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 187.276 and h = 1.07352e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 426.791 and h = 2.71877e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 186.791 and h = 8.33308e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 426.324 and h = 6.40938e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 186.324 and h = 6.2971e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 425.872 and h = 5.22656e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 185.871 and h = 8.74472e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 425.433 and h = 6.45642e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 185.432 and h = 1.24738e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 425.005 and h = 2.44231e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 185 and h = 1.52451e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 424.587 and h = 1.17106e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 184.587 and h = 1.33604e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 117.659 and h = 3.47241e-10, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 424.178 and h = 9.33117e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 136.209 and h = 8.35194e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 423.776 and h = 3.22015e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 183.776 and h = 1.66384e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 366.89 and h = 6.96452e-10, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 183.381 and h = 7.50928e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 422.992 and h = 4.10533e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 182.992 and h = 5.41809e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 422.608 and h = 1.23314e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 182.608 and h = 1.1319e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 331.865 and h = 7.0622e-10, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 182.229 and h = 2.76678e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# 正在计算循环 18 ...
# At t = 429.689 and h = 1.24737e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 189.689 and h = 9.66951e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 428.881 and h = 9.84615e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 188.881 and h = 1.53332e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 428.316 and h = 7.14908e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 188.316 and h = 8.72162e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 324.035 and h = 2.6291e-10, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 187.783 and h = 1.0086e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 427.276 and h = 8.52486e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 187.276 and h = 1.07352e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 426.791 and h = 2.71877e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 186.791 and h = 8.33308e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 426.324 and h = 6.40938e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 186.324 and h = 6.2971e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 425.872 and h = 5.22656e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 185.871 and h = 8.74472e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 425.433 and h = 6.45642e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 185.432 and h = 1.24738e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 425.005 and h = 2.44231e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 185 and h = 1.52451e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 424.587 and h = 1.17106e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 184.587 and h = 1.33604e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 117.659 and h = 3.47241e-10, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 424.178 and h = 9.33117e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 136.209 and h = 8.35194e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 423.776 and h = 3.22015e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 183.776 and h = 1.66384e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 366.89 and h = 6.96452e-10, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 183.381 and h = 7.50928e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 422.992 and h = 4.10533e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 182.992 and h = 5.41809e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 422.608 and h = 1.23314e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 182.608 and h = 1.1319e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 331.865 and h = 7.0622e-10, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 182.229 and h = 2.76678e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 421.854 and h = 1.01675e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 181.854 and h = 1.73921e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# 正在计算循环 19 ...
# At t = 429.689 and h = 1.24737e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 189.689 and h = 9.66951e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 428.881 and h = 9.84615e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 188.881 and h = 1.53332e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 428.316 and h = 7.14908e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 188.316 and h = 8.72162e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 324.035 and h = 2.6291e-10, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 187.783 and h = 1.0086e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 427.276 and h = 8.52486e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 187.276 and h = 1.07352e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 426.791 and h = 2.71877e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 186.791 and h = 8.33308e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 426.324 and h = 6.40938e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 186.324 and h = 6.2971e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 425.872 and h = 5.22656e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 185.871 and h = 8.74472e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 425.433 and h = 6.45642e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 185.432 and h = 1.24738e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 425.005 and h = 2.44231e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 185 and h = 1.52451e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 424.587 and h = 1.17106e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 184.587 and h = 1.33604e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 117.659 and h = 3.47241e-10, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 424.178 and h = 9.33117e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 136.209 and h = 8.35194e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 423.776 and h = 3.22015e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 183.776 and h = 1.66384e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 366.89 and h = 6.96452e-10, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 183.381 and h = 7.50928e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 422.992 and h = 4.10533e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 182.992 and h = 5.41809e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 422.608 and h = 1.23314e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 182.608 and h = 1.1319e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 331.865 and h = 7.0622e-10, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 182.229 and h = 2.76678e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 421.854 and h = 1.01675e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 181.854 and h = 1.73921e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 421.478 and h = 6.09343e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 181.483 and h = 1.0249e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# 正在计算循环 20 ...
# At t = 429.689 and h = 1.24737e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 189.689 and h = 9.66951e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 428.881 and h = 9.84615e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 188.881 and h = 1.53332e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 428.316 and h = 7.14908e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 188.316 and h = 8.72162e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 324.035 and h = 2.6291e-10, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 187.783 and h = 1.0086e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 427.276 and h = 8.52486e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 187.276 and h = 1.07352e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 426.791 and h = 2.71877e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 186.791 and h = 8.33308e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 426.324 and h = 6.40938e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 186.324 and h = 6.2971e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 425.872 and h = 5.22656e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 185.871 and h = 8.74472e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 425.433 and h = 6.45642e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 185.432 and h = 1.24738e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 425.005 and h = 2.44231e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 185 and h = 1.52451e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 424.587 and h = 1.17106e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 184.587 and h = 1.33604e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 117.659 and h = 3.47241e-10, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 424.178 and h = 9.33117e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 136.209 and h = 8.35194e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 423.776 and h = 3.22015e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 183.776 and h = 1.66384e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 366.89 and h = 6.96452e-10, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 183.381 and h = 7.50928e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 422.992 and h = 4.10533e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 182.992 and h = 5.41809e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 422.608 and h = 1.23314e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 182.608 and h = 1.1319e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 331.865 and h = 7.0622e-10, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 182.229 and h = 2.76678e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 421.854 and h = 1.01675e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 181.854 and h = 1.73921e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 421.478 and h = 6.09343e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 181.483 and h = 1.0249e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 421.114 and h = 5.39594e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 181.114 and h = 7.20168e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# 正在计算循环 21 ...
# At t = 429.689 and h = 1.24737e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 189.689 and h = 9.66951e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 428.881 and h = 9.84615e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 188.881 and h = 1.53332e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 428.316 and h = 7.14908e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 188.316 and h = 8.72162e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 324.035 and h = 2.6291e-10, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 187.783 and h = 1.0086e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 427.276 and h = 8.52486e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 187.276 and h = 1.07352e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 426.791 and h = 2.71877e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 186.791 and h = 8.33308e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 426.324 and h = 6.40938e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 186.324 and h = 6.2971e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 425.872 and h = 5.22656e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 185.871 and h = 8.74472e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 425.433 and h = 6.45642e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 185.432 and h = 1.24738e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 425.005 and h = 2.44231e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 185 and h = 1.52451e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 424.587 and h = 1.17106e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 184.587 and h = 1.33604e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 117.659 and h = 3.47241e-10, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 424.178 and h = 9.33117e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 136.209 and h = 8.35194e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 423.776 and h = 3.22015e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 183.776 and h = 1.66384e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 366.89 and h = 6.96452e-10, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 183.381 and h = 7.50928e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 422.992 and h = 4.10533e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 182.992 and h = 5.41809e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 422.608 and h = 1.23314e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 182.608 and h = 1.1319e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 331.865 and h = 7.0622e-10, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 182.229 and h = 2.76678e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 421.854 and h = 1.01675e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 181.854 and h = 1.73921e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 421.478 and h = 6.09343e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 181.483 and h = 1.0249e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 421.114 and h = 5.39594e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 181.114 and h = 7.20168e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 420.746 and h = 1.48597e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 180.746 and h = 1.63742e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# 正在计算循环 22 ...
# At t = 429.689 and h = 1.24737e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# ...
# At t = 180.746 and h = 1.63742e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 420.38 and h = 2.12354e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 103.946 and h = 2.55105e-10, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 420.014 and h = 7.75364e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 180.015 and h = 4.62324e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 419.65 and h = 5.21897e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 179.65 and h = 1.52972e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 419.288 and h = 6.19674e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 179.288 and h = 1.18318e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 418.927 and h = 1.23316e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 178.927 and h = 1.24956e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 418.567 and h = 1.39981e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 178.568 and h = 3.31217e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 418.211 and h = 4.05071e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 178.211 and h = 1.39478e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 417.858 and h = 6.47315e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 177.858 and h = 4.87238e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 417.509 and h = 1.72378e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 177.509 and h = 2.48581e-13, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 417.163 and h = 1.48614e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 177.163 and h = 3.64265e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 416.822 and h = 6.6778e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 176.821 and h = 9.41361e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 416.484 and h = 1.20917e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 176.485 and h = 5.36616e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 416.152 and h = 6.19809e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 176.152 and h = 3.73716e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 415.824 and h = 5.38699e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 175.825 and h = 4.14512e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 415.503 and h = 1.05303e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.789 and h = 1.12736e-10, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 415.185 and h = 9.52376e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 175.185 and h = 7.01969e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 414.873 and h = 1.62772e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 174.873 and h = 1.72081e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 414.566 and h = 6.21401e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 174.566 and h = 5.09926e-13, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 414.263 and h = 1.5367e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 174.263 and h = 9.82839e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 325.429 and h = 8.76189e-10, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 173.965 and h = 8.363e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 413.672 and h = 1.24601e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 173.672 and h = 2.87768e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 413.384 and h = 8.92241e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 173.384 and h = 8.77602e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 413.099 and h = 7.9108e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 173.099 and h = 1.77746e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 412.819 and h = 3.88842e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 172.819 and h = 1.19684e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 412.544 and h = 4.53273e-13, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 172.544 and h = 7.4776e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 412.271 and h = 5.27e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 172.271 and h = 1.10299e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 412.002 and h = 1.02008e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 172.002 and h = 7.74273e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 411.736 and h = 2.59993e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 171.736 and h = 9.75024e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 411.474 and h = 3.4044e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 171.474 and h = 9.49164e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 411.214 and h = 1.17619e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 171.214 and h = 3.45879e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 410.957 and h = 1.66068e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 170.957 and h = 9.22192e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 373.272 and h = 2.31543e-10, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 170.703 and h = 9.97627e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 410.451 and h = 1.59744e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 170.451 and h = 5.28279e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 410.202 and h = 4.16508e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 170.202 and h = 5.53095e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 409.956 and h = 7.16199e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 169.956 and h = 9.8966e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 409.712 and h = 9.90401e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 169.712 and h = 5.35425e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 409.469 and h = 8.43549e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 169.469 and h = 1.20273e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 409.229 and h = 1.46386e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 169.229 and h = 1.01033e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 408.991 and h = 1.04431e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 168.992 and h = 7.89058e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 408.755 and h = 1.51742e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 168.755 and h = 9.50358e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 408.516 and h = 2.94525e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 168.521 and h = 7.6453e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 408.288 and h = 1.68039e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 168.288 and h = 4.06761e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 408.057 and h = 4.94501e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 168.057 and h = 9.27485e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 407.826 and h = 1.7077e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 167.827 and h = 1.17671e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 407.599 and h = 9.37084e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 167.598 and h = 1.4588e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 407.372 and h = 1.18742e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 167.366 and h = 3.50927e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 407.146 and h = 5.93215e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 167.146 and h = 7.78063e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 406.922 and h = 6.81937e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 166.922 and h = 8.6964e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 406.699 and h = 9.48949e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 166.699 and h = 1.57991e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 406.478 and h = 6.49891e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 166.477 and h = 2.186e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 406.257 and h = 1.14502e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 166.257 and h = 1.1064e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 406.037 and h = 1.54481e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 166.037 and h = 7.12178e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 405.819 and h = 1.12955e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 165.819 and h = 7.42074e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 405.601 and h = 1.1438e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 165.602 and h = 8.7178e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 405.381 and h = 1.03133e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 165.385 and h = 1.15927e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 405.17 and h = 1.5413e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 165.17 and h = 1.18066e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 404.955 and h = 1.05859e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 164.955 and h = 1.16072e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 404.742 and h = 3.26922e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 164.742, repeated recoverable residual errors.
# At t = 333.734 and h = 1.06153e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 164.528 and h = 1.18965e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 404.316 and h = 7.04192e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 164.316 and h = 2.0077e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 404.105 and h = 3.08305e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 164.105 and h = 8.75072e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 403.894 and h = 8.87503e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 163.894 and h = 3.1497e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 403.685 and h = 3.77181e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 163.685 and h = 3.37581e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 403.476 and h = 3.93937e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 163.476 and h = 5.68651e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 403.267 and h = 6.33408e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 163.267 and h = 1.04846e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 403.059 and h = 3.86471e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 163.059 and h = 7.09584e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 402.852 and h = 8.09708e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 162.852 and h = 3.55377e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 402.646 and h = 6.39944e-13, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 91.9902 and h = 1.3093e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 402.439 and h = 1.74269e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 93.6676 and h = 1.12363e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 402.234 and h = 1.13786e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 162.234 and h = 1.02812e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 402.029 and h = 4.21215e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 162.029 and h = 2.68045e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 401.825 and h = 1.52485e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 161.825 and h = 9.93312e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 401.621 and h = 1.17143e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 161.621 and h = 7.93283e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 401.418 and h = 5.21593e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 161.417 and h = 1.62261e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 401.214 and h = 5.47167e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 161.214 and h = 9.10385e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 401.012 and h = 1.91076e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 73.0982 and h = 1.41329e-10, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 73.0994 and h = 1.42421e-10, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 400.809 and h = 1.083e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 160.809 and h = 5.38743e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 303.343 and h = 4.5119e-10, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 160.608 and h = 1.1028e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 400.406 and h = 1.17867e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 160.406 and h = 5.29287e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# 当 k=100 时，剩余容量为: 98.97%
