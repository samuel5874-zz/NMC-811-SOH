# %%
# Install necessary libraries
# %pip install "pybamm[plot,cite]" -q

import pybamm
import matplotlib.pyplot as plt

# Define the battery model
model = pybamm.lithium_ion.DFN(
    {
        "SEI": "solvent-diffusion limited",
        "SEI porosity change": "true",
        "lithium plating": "partially reversible",
        "lithium plating porosity change": "true",  # alias for "SEI porosity change"
        "particle mechanics": ("swelling and cracking", "swelling only"),
        "SEI on cracks": "true",
        "loss of active material": "stress-driven",
        "calculate discharge energy": "true",  # for compatibility with older PyBaMM versions
    }
)

# Set the model parameters
param = pybamm.ParameterValues("OKane2022")
var_pts = {
    "x_n": 5,  # Negative electrode
    "x_s": 5,  # Separator
    "x_p": 5,  # Positive electrode
    "r_n": 30,  # Negative electrode particle
    "r_p": 30,  # Positive electrode particle
}

# Set the maximum number of cycles
max_cycles = 100  # You can increase it to 2000, but the computation will be large
cycle_numbers = list(range(1, max_cycles + 1))  # k = 1, ..., max_cycles
remaining_capacity_values = []  # Store remaining capacity

# Simulate step-by-step with increasing cycles
for k in cycle_numbers:
    print(f"Calculating cycle {k} ...")  # Display current progress

    # Define the experiment protocol
    exp_k = pybamm.Experiment(
        [
            "Hold at 4.2 V until C/100 (5 minute period)",
            "Rest for 4 hours (5 minute period)",
            "Discharge at 0.1C until 2.5 V (5 minute period)",  # Initial capacity check
            "Charge at 0.3C until 4.2 V (5 minute period)",
            "Hold at 4.2 V until C/100 (5 minute period)",
        ]
        + [
            (
                "Discharge at 2C until 2.5 V",  # Aging cycles
                "Charge at 0.3C until 4.2 V (5 minute period)",
                "Hold at 4.2 V until C/100 (5 minute period)",
            )
        ]
        * k
        + ["Discharge at 0.1C until 2.5 V (5 minute period)"],  # Final capacity check
    )

    # Run the simulation
    sim_k = pybamm.Simulation(model, parameter_values=param, experiment=exp_k, var_pts=var_pts)
    sol_k = sim_k.solve()

    # Extract LLI loss (in A.h) and calculate Remaining Capacity (%)
    Q_LLI_final_k = sol_k["Total lithium lost [mol]"].entries[-1] * 96485.3 / 3600  # Convert units
    remaining_capacity_k = (5 - Q_LLI_final_k) / 5 * 100  # Calculate remaining capacity percentage
    remaining_capacity_values.append(remaining_capacity_k)  # Store data

# Plot Remaining Capacity (%) vs. Cycle Number (k)
plt.figure(figsize=(8, 6))
plt.plot(cycle_numbers, remaining_capacity_values, label="Remaining Capacity (%)", color="blue", linewidth=2)
plt.xlabel("Number of cycles (k)")
plt.ylabel("Remaining Capacity (%)")
plt.title("Remaining Capacity vs. Cycle Number")
plt.legend()
plt.grid(True)
plt.ylim(0, 100)  # Limit the y-axis range to 0% - 100%
plt.show()
print(f"At k=100, the remaining capacity is: {remaining_capacity_values[-1]:.2f}%")
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Calculating cycle 1 ...
# At t = 151.273 and h = 2.83539e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 151.273 and h = 1.24686e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# Calculating cycle 2 ...
# At t = 151.273 and h = 2.83539e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 151.273 and h = 1.24686e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.97 and h = 4.10172e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.97 and h = 1.74737e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# Calculating cycle 3 ...
# At t = 151.273 and h = 2.83539e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 151.273 and h = 1.24686e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.97 and h = 4.10172e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.97 and h = 1.74737e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.681 and h = 2.07904e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.681 and h = 2.34404e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# Calculating cycle 4 ...
# At t = 151.273 and h = 2.83539e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 151.273 and h = 1.24686e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.97 and h = 4.10172e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.97 and h = 1.74737e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.681 and h = 2.07904e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.681 and h = 2.34404e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.404 and h = 2.42423e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.404 and h = 2.0617e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# Calculating cycle 5 ...
# At t = 151.273 and h = 2.83539e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 151.273 and h = 1.24686e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.97 and h = 4.10172e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.97 and h = 1.74737e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.681 and h = 2.07904e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.681 and h = 2.34404e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.404 and h = 2.42423e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.404 and h = 2.0617e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.136 and h = 2.50451e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.136 and h = 3.34076e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# Calculating cycle 6 ...
# At t = 151.273 and h = 2.83539e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 151.273 and h = 1.24686e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.97 and h = 4.10172e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.97 and h = 1.74737e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.681 and h = 2.07904e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.681 and h = 2.34404e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.404 and h = 2.42423e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.404 and h = 2.0617e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.136 and h = 2.50451e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.136 and h = 3.34076e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.876 and h = 2.17318e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.876 and h = 6.54805e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# Calculating cycle 7 ...
# At t = 151.273 and h = 2.83539e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 151.273 and h = 1.24686e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.97 and h = 4.10172e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.97 and h = 1.74737e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.681 and h = 2.07904e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.681 and h = 2.34404e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.404 and h = 2.42423e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.404 and h = 2.0617e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.136 and h = 2.50451e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.136 and h = 3.34076e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.876 and h = 2.17318e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.876 and h = 6.54805e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.623 and h = 4.20137e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.623 and h = 5.11846e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# Calculating cycle 8 ...
# At t = 151.273 and h = 2.83539e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 151.273 and h = 1.24686e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.97 and h = 4.10172e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.97 and h = 1.74737e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.681 and h = 2.07904e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.681 and h = 2.34404e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.404 and h = 2.42423e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.404 and h = 2.0617e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.136 and h = 2.50451e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.136 and h = 3.34076e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.876 and h = 2.17318e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.876 and h = 6.54805e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.623 and h = 4.20137e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.623 and h = 5.11846e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.376 and h = 5.60331e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.376 and h = 4.8421e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# Calculating cycle 9 ...
# At t = 151.273 and h = 2.83539e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 151.273 and h = 1.24686e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.97 and h = 4.10172e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.97 and h = 1.74737e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.681 and h = 2.07904e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.681 and h = 2.34404e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.404 and h = 2.42423e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.404 and h = 2.0617e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.136 and h = 2.50451e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.136 and h = 3.34076e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.876 and h = 2.17318e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.876 and h = 6.54805e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.623 and h = 4.20137e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.623 and h = 5.11846e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.376 and h = 5.60331e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.376 and h = 4.8421e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.136 and h = 2.2733e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.135 and h = 4.00546e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# Calculating cycle 10 ...
# At t = 151.273 and h = 2.83539e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 151.273 and h = 1.24686e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.97 and h = 4.10172e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.97 and h = 1.74737e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.681 and h = 2.07904e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.681 and h = 2.34404e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.404 and h = 2.42423e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.404 and h = 2.0617e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.136 and h = 2.50451e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.136 and h = 3.34076e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.876 and h = 2.17318e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.876 and h = 6.54805e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.623 and h = 4.20137e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.623 and h = 5.11846e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.376 and h = 5.60331e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.376 and h = 4.8421e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.136 and h = 2.2733e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.135 and h = 4.00546e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.9 and h = 6.86507e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.9 and h = 2.11512e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# Calculating cycle 11 ...
# At t = 151.273 and h = 2.83539e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 151.273 and h = 1.24686e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.97 and h = 4.10172e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.97 and h = 1.74737e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.681 and h = 2.07904e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.681 and h = 2.34404e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.404 and h = 2.42423e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.404 and h = 2.0617e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.136 and h = 2.50451e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.136 and h = 3.34076e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.876 and h = 2.17318e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.876 and h = 6.54805e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.623 and h = 4.20137e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.623 and h = 5.11846e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.376 and h = 5.60331e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.376 and h = 4.8421e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.136 and h = 2.2733e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.135 and h = 4.00546e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.9 and h = 6.86507e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.9 and h = 2.11512e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.67 and h = 3.12788e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.67 and h = 5.72986e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# Calculating cycle 12 ...
# At t = 151.273 and h = 2.83539e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 151.273 and h = 1.24686e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.97 and h = 4.10172e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.97 and h = 1.74737e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.681 and h = 2.07904e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.681 and h = 2.34404e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.404 and h = 2.42423e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.404 and h = 2.0617e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.136 and h = 2.50451e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.136 and h = 3.34076e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.876 and h = 2.17318e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.876 and h = 6.54805e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.623 and h = 4.20137e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.623 and h = 5.11846e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.376 and h = 5.60331e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.376 and h = 4.8421e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.136 and h = 2.2733e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.135 and h = 4.00546e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.9 and h = 6.86507e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.9 and h = 2.11512e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.67 and h = 3.12788e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.67 and h = 5.72986e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.445 and h = 1.17836e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.444 and h = 2.21166e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# Calculating cycle 13 ...
# At t = 151.273 and h = 2.83539e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 151.273 and h = 1.24686e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.97 and h = 4.10172e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.97 and h = 1.74737e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.681 and h = 2.07904e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.681 and h = 2.34404e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.404 and h = 2.42423e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.404 and h = 2.0617e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.136 and h = 2.50451e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.136 and h = 3.34076e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.876 and h = 2.17318e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.876 and h = 6.54805e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.623 and h = 4.20137e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.623 and h = 5.11846e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.376 and h = 5.60331e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.376 and h = 4.8421e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.136 and h = 2.2733e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.135 and h = 4.00546e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.9 and h = 6.86507e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.9 and h = 2.11512e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.67 and h = 3.12788e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.67 and h = 5.72986e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.445 and h = 1.17836e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.444 and h = 2.21166e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.224 and h = 7.98483e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.224 and h = 2.6956e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# Calculating cycle 14 ...
# At t = 151.273 and h = 2.83539e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 151.273 and h = 1.24686e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.97 and h = 4.10172e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.97 and h = 1.74737e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.681 and h = 2.07904e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.681 and h = 2.34404e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.404 and h = 2.42423e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.404 and h = 2.0617e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.136 and h = 2.50451e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.136 and h = 3.34076e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.876 and h = 2.17318e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.876 and h = 6.54805e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.623 and h = 4.20137e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.623 and h = 5.11846e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.376 and h = 5.60331e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.376 and h = 4.8421e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.136 and h = 2.2733e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.135 and h = 4.00546e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.9 and h = 6.86507e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.9 and h = 2.11512e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.67 and h = 3.12788e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.67 and h = 5.72986e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.445 and h = 1.17836e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.444 and h = 2.21166e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.224 and h = 7.98483e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.224 and h = 2.6956e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.008 and h = 5.54479e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.008 and h = 4.44745e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# Calculating cycle 15 ...
# At t = 151.273 and h = 2.83539e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 151.273 and h = 1.24686e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.97 and h = 4.10172e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.97 and h = 1.74737e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.681 and h = 2.07904e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.681 and h = 2.34404e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.404 and h = 2.42423e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.404 and h = 2.0617e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.136 and h = 2.50451e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.136 and h = 3.34076e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.876 and h = 2.17318e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.876 and h = 6.54805e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.623 and h = 4.20137e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.623 and h = 5.11846e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.376 and h = 5.60331e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.376 and h = 4.8421e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.136 and h = 2.2733e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.135 and h = 4.00546e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.9 and h = 6.86507e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.9 and h = 2.11512e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.67 and h = 3.12788e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.67 and h = 5.72986e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.445 and h = 1.17836e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.444 and h = 2.21166e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.224 and h = 7.98483e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.224 and h = 2.6956e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.008 and h = 5.54479e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.008 and h = 4.44745e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 147.797 and h = 1.17438e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 147.797 and h = 5.69578e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# Calculating cycle 16 ...
# At t = 151.273 and h = 2.83539e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 151.273 and h = 1.24686e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.97 and h = 4.10172e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.97 and h = 1.74737e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.681 and h = 2.07904e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.681 and h = 2.34404e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.404 and h = 2.42423e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.404 and h = 2.0617e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.136 and h = 2.50451e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.136 and h = 3.34076e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.876 and h = 2.17318e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.876 and h = 6.54805e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.623 and h = 4.20137e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.623 and h = 5.11846e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.376 and h = 5.60331e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.376 and h = 4.8421e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.136 and h = 2.2733e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.135 and h = 4.00546e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.9 and h = 6.86507e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.9 and h = 2.11512e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.67 and h = 3.12788e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.67 and h = 5.72986e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.445 and h = 1.17836e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.444 and h = 2.21166e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.224 and h = 7.98483e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.224 and h = 2.6956e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.008 and h = 5.54479e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.008 and h = 4.44745e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 147.797 and h = 1.17438e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 147.797 and h = 5.69578e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 147.59 and h = 3.15992e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 147.59 and h = 3.24247e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# Calculating cycle 17 ...
# At t = 151.273 and h = 2.83539e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 151.273 and h = 1.24686e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.97 and h = 4.10172e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.97 and h = 1.74737e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.681 and h = 2.07904e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.681 and h = 2.34404e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.404 and h = 2.42423e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.404 and h = 2.0617e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.136 and h = 2.50451e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.136 and h = 3.34076e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.876 and h = 2.17318e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.876 and h = 6.54805e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.623 and h = 4.20137e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.623 and h = 5.11846e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.376 and h = 5.60331e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.376 and h = 4.8421e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.136 and h = 2.2733e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.135 and h = 4.00546e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.9 and h = 6.86507e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.9 and h = 2.11512e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.67 and h = 3.12788e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.67 and h = 5.72986e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.445 and h = 1.17836e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.444 and h = 2.21166e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.224 and h = 7.98483e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.224 and h = 2.6956e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.008 and h = 5.54479e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.008 and h = 4.44745e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 147.797 and h = 1.17438e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 147.797 and h = 5.69578e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 147.59 and h = 3.15992e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 147.59 and h = 3.24247e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 147.387 and h = 3.21963e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 147.387 and h = 5.62158e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# Calculating cycle 18 ...
# At t = 151.273 and h = 2.83539e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 151.273 and h = 1.24686e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.97 and h = 4.10172e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.97 and h = 1.74737e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.681 and h = 2.07904e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.681 and h = 2.34404e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.404 and h = 2.42423e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.404 and h = 2.0617e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.136 and h = 2.50451e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.136 and h = 3.34076e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.876 and h = 2.17318e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.876 and h = 6.54805e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.623 and h = 4.20137e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.623 and h = 5.11846e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.376 and h = 5.60331e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.376 and h = 4.8421e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.136 and h = 2.2733e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.135 and h = 4.00546e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.9 and h = 6.86507e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.9 and h = 2.11512e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.67 and h = 3.12788e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.67 and h = 5.72986e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.445 and h = 1.17836e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.444 and h = 2.21166e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.224 and h = 7.98483e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.224 and h = 2.6956e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.008 and h = 5.54479e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.008 and h = 4.44745e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 147.797 and h = 1.17438e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 147.797 and h = 5.69578e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 147.59 and h = 3.15992e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 147.59 and h = 3.24247e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 147.387 and h = 3.21963e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 147.387 and h = 5.62158e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 147.188, repeated recoverable residual errors.
# At t = 147.188 and h = 3.94221e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# Calculating cycle 19 ...
# At t = 151.273 and h = 2.83539e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 151.273 and h = 1.24686e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.97 and h = 4.10172e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.97 and h = 1.74737e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.681 and h = 2.07904e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.681 and h = 2.34404e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.404 and h = 2.42423e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.404 and h = 2.0617e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.136 and h = 2.50451e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.136 and h = 3.34076e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.876 and h = 2.17318e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.876 and h = 6.54805e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.623 and h = 4.20137e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.623 and h = 5.11846e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.376 and h = 5.60331e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.376 and h = 4.8421e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.136 and h = 2.2733e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.135 and h = 4.00546e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.9 and h = 6.86507e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.9 and h = 2.11512e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.67 and h = 3.12788e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.67 and h = 5.72986e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.445 and h = 1.17836e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.444 and h = 2.21166e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.224 and h = 7.98483e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.224 and h = 2.6956e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.008 and h = 5.54479e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.008 and h = 4.44745e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 147.797 and h = 1.17438e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 147.797 and h = 5.69578e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 147.59 and h = 3.15992e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 147.59 and h = 3.24247e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 147.387 and h = 3.21963e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 147.387 and h = 5.62158e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 147.188, repeated recoverable residual errors.
# At t = 147.188 and h = 3.94221e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 146.993 and h = 1.10291e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 146.993 and h = 2.23103e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# Calculating cycle 20 ...
# At t = 151.273 and h = 2.83539e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 151.273 and h = 1.24686e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.97 and h = 4.10172e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.97 and h = 1.74737e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.681 and h = 2.07904e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.681 and h = 2.34404e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.404 and h = 2.42423e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.404 and h = 2.0617e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.136 and h = 2.50451e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.136 and h = 3.34076e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.876 and h = 2.17318e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.876 and h = 6.54805e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.623 and h = 4.20137e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.623 and h = 5.11846e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.376 and h = 5.60331e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.376 and h = 4.8421e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.136 and h = 2.2733e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.135 and h = 4.00546e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.9 and h = 6.86507e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.9 and h = 2.11512e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.67 and h = 3.12788e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.67 and h = 5.72986e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.445 and h = 1.17836e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.444 and h = 2.21166e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.224 and h = 7.98483e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.224 and h = 2.6956e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.008 and h = 5.54479e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.008 and h = 4.44745e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 147.797 and h = 1.17438e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 147.797 and h = 5.69578e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 147.59 and h = 3.15992e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 147.59 and h = 3.24247e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 147.387 and h = 3.21963e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 147.387 and h = 5.62158e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 147.188, repeated recoverable residual errors.
# At t = 147.188 and h = 3.94221e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 146.993 and h = 1.10291e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 146.993 and h = 2.23103e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 146.802 and h = 3.91983e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 146.802 and h = 3.68962e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 94.768 and h = 2.29826e-10, the corrector convergence failed repeatedly or with |h| = hmin.
# Calculating cycle 21 ...
# At t = 151.273 and h = 2.83539e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 151.273 and h = 1.24686e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.97 and h = 4.10172e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.97 and h = 1.74737e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.681 and h = 2.07904e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.681 and h = 2.34404e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.404 and h = 2.42423e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.404 and h = 2.0617e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.136 and h = 2.50451e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.136 and h = 3.34076e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.876 and h = 2.17318e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.876 and h = 6.54805e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.623 and h = 4.20137e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.623 and h = 5.11846e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.376 and h = 5.60331e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.376 and h = 4.8421e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.136 and h = 2.2733e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.135 and h = 4.00546e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.9 and h = 6.86507e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.9 and h = 2.11512e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.67 and h = 3.12788e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.67 and h = 5.72986e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.445 and h = 1.17836e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.444 and h = 2.21166e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.224 and h = 7.98483e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.224 and h = 2.6956e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.008 and h = 5.54479e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.008 and h = 4.44745e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 147.797 and h = 1.17438e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 147.797 and h = 5.69578e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 147.59 and h = 3.15992e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 147.59 and h = 3.24247e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 147.387 and h = 3.21963e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 147.387 and h = 5.62158e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 147.188, repeated recoverable residual errors.
# At t = 147.188 and h = 3.94221e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 146.993 and h = 1.10291e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 146.993 and h = 2.23103e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 146.802 and h = 3.91983e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 146.802 and h = 3.68962e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 94.768 and h = 2.29826e-10, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 146.615 and h = 3.01832e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 146.615 and h = 4.19917e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# Calculating cycle 22 ...
# At t = 151.273 and h = 2.83539e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 151.273 and h = 1.24686e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.97 and h = 4.10172e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.97 and h = 1.74737e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.681 and h = 2.07904e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.681 and h = 2.34404e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.404 and h = 2.42423e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.404 and h = 2.0617e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.136 and h = 2.50451e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 150.136 and h = 3.34076e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.876 and h = 2.17318e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.876 and h = 6.54805e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 149.623 and h = 4.20137e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# ...
# At t = 94.768 and h = 2.29826e-10, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 146.615 and h = 3.01832e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 146.615 and h = 4.19917e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 146.431 and h = 3.77704e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 146.431 and h = 4.63464e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 146.25 and h = 1.60731e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 146.25 and h = 2.81459e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 146.072 and h = 4.73802e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 146.072 and h = 7.30482e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 145.897 and h = 4.22347e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 93.5467 and h = 1.7082e-10, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 145.725 and h = 6.57761e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 145.725 and h = 1.33891e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 145.555 and h = 4.98601e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 145.555 and h = 4.83384e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 145.388 and h = 2.05833e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 145.388 and h = 2.32491e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 145.223 and h = 3.50228e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 145.223 and h = 3.49541e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 145.061 and h = 1.2517e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 145.061, repeated recoverable residual errors.
# At t = 144.901 and h = 5.77565e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 144.901 and h = 1.54454e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 144.742 and h = 4.06138e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 144.742 and h = 2.68017e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 144.586 and h = 5.28097e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 144.583 and h = 1.64274e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 144.432 and h = 7.97478e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 144.432 and h = 4.85364e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 144.279 and h = 2.51293e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 144.279 and h = 4.46524e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 144.129 and h = 3.82056e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 144.129 and h = 7.93463e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 143.98 and h = 1.57602e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 143.98 and h = 5.34975e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 143.832 and h = 1.41152e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 143.832 and h = 5.85391e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 143.687 and h = 1.68148e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 143.687 and h = 3.37901e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 143.542 and h = 4.67433e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 143.542 and h = 3.36777e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 143.4 and h = 7.36166e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 143.4 and h = 3.84047e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 143.258 and h = 4.54032e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 143.258 and h = 3.7178e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 143.118 and h = 4.90252e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 143.118 and h = 3.58979e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 142.98, repeated recoverable residual errors.
# At t = 142.98 and h = 3.59292e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 142.843 and h = 2.11916e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 142.843 and h = 5.73815e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 142.707 and h = 4.16331e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 142.707 and h = 1.42085e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 142.572 and h = 3.62546e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 142.572 and h = 1.25531e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 142.438 and h = 2.53641e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 142.438 and h = 3.67058e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 142.306 and h = 2.35885e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 142.305 and h = 5.4856e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 142.172 and h = 8.23859e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 142.174 and h = 3.05467e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 142.044 and h = 3.09266e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 142.044 and h = 1.77123e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 141.914 and h = 5.84808e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 141.914 and h = 2.66003e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 141.786 and h = 5.64241e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 141.786 and h = 2.01585e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 141.658 and h = 2.48545e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 141.658, repeated recoverable residual errors.
# At t = 105.071 and h = 9.17489e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 141.531 and h = 2.06756e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 141.531 and h = 3.13771e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 141.406 and h = 2.45893e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 141.389 and h = 1.53764e-13, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 141.281 and h = 1.71083e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 141.28 and h = 4.45333e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 141.156 and h = 4.96572e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 141.156 and h = 4.15549e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 141.033 and h = 5.70457e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 141.033 and h = 2.04815e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 140.91 and h = 3.92318e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 140.91 and h = 1.95439e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 140.789 and h = 1.56057e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 140.789 and h = 3.47659e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 140.667 and h = 3.69741e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 140.667 and h = 4.65501e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 140.547 and h = 4.56331e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 140.547 and h = 2.20277e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 89.1228 and h = 1.7103e-10, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 140.427 and h = 2.25092e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 140.427 and h = 5.29082e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 140.308 and h = 3.53359e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 140.308 and h = 3.01459e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 140.19 and h = 4.16251e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 140.19 and h = 5.16082e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 140.072 and h = 3.50102e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 140.072 and h = 1.56056e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 139.955 and h = 3.13703e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 139.955 and h = 3.77558e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 95.8888 and h = 1.69281e-10, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 139.838 and h = 3.11751e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 139.722 and h = 2.68728e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 139.722, , mxstep steps taken before reaching tout.
# At t = 139.607 and h = 7.16271e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 139.607 and h = 2.27468e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 139.492 and h = 2.64296e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 139.492 and h = 1.73196e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 139.378 and h = 1.45691e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 139.378, repeated recoverable residual errors.
# At t = 139.264, repeated recoverable residual errors.
# At t = 121.038 and h = 1.75162e-10, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 139.151 and h = 2.79437e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 139.151 and h = 7.99374e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 139.038 and h = 2.93316e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 139.038 and h = 2.18403e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 138.926 and h = 2.04343e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 138.926 and h = 3.91538e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 138.814 and h = 3.24738e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 138.814 and h = 1.75826e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 138.703 and h = 3.04667e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 138.703, repeated recoverable residual errors.
# At t = 138.592 and h = 2.70667e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 138.592 and h = 3.10372e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 138.482 and h = 1.58171e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 138.482 and h = 5.77308e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 138.372 and h = 9.12923e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 138.372 and h = 5.49161e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 138.263 and h = 2.19982e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 138.263, repeated recoverable residual errors.
# At t = 138.154 and h = 1.34908e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 138.154 and h = 1.22643e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 138.045 and h = 5.06494e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 138.045 and h = 3.69371e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 137.937 and h = 4.87613e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 137.937 and h = 4.05462e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 137.829 and h = 2.71191e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 137.83 and h = 3.23742e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 137.722 and h = 1.23855e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 137.722 and h = 4.09474e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 137.615 and h = 4.54176e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 137.615 and h = 1.11708e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 137.509 and h = 4.62202e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 137.509 and h = 1.74075e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 137.403 and h = 3.24834e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 97.5651 and h = 2.9589e-10, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 137.297 and h = 4.73225e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 137.297 and h = 1.74805e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 137.191 and h = 3.82876e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 137.191 and h = 1.62513e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 137.086 and h = 1.38828e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 137.086 and h = 1.13418e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 136.982 and h = 2.21432e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 136.982 and h = 1.62912e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 136.877 and h = 2.58332e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 136.877 and h = 2.61587e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 136.773 and h = 1.21491e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 136.773 and h = 2.9393e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 136.669 and h = 2.69517e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 136.665 and h = 4.03922e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 136.566 and h = 4.046e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 136.566 and h = 1.49625e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 136.463 and h = 4.36368e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 136.463 and h = 4.36234e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At k=100, the remaining capacity is: 99.01%
