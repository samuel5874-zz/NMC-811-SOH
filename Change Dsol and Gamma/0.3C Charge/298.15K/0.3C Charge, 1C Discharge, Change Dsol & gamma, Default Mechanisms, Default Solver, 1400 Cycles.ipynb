# %%
# Install necessary libraries
# %pip install "pybamm[plot,cite]" -q

import pybamm
import matplotlib.pyplot as plt

# Define the battery model
model = pybamm.lithium_ion.DFN(
    {
        "SEI": "solvent-diffusion limited",
        "SEI porosity change": "true",
        "lithium plating": "partially reversible",
        "lithium plating porosity change": "true",  # alias for "SEI porosity change"
        "particle mechanics": ("swelling and cracking", "swelling only"),
        "SEI on cracks": "true",
        "loss of active material": "stress-driven",
        "calculate discharge energy": "true",  # for compatibility with older PyBaMM versions
    }
)

# Set model parameters
param = pybamm.ParameterValues("OKane2022")
param.update({
    "SEI solvent diffusivity [m2.s-1]": 2e-21,  # The new value can be adjusted as needed
    'Dead lithium decay constant [s-1]': 7.5e-5,
})

var_pts = {
    "x_n": 5,  # Negative electrode
    "x_s": 5,  # Separator
    "x_p": 5,  # Positive electrode
    "r_n": 30,  # Negative electrode particles
    "r_p": 30,  # Positive electrode particles
}

# Set the target number of cycles
target_cycle = 1400

print(f"Calculating cycle {target_cycle} ...")

# Define the experimental protocol
exp_k = pybamm.Experiment(
        [(
            "Discharge at 0.3C until 2.5 V",
            "Charge at 0.3C until 4.2 V (5 minute period)",
            "Hold at 4.2 V until C/100 (5 minute period)",
        )]
    * target_cycle
    + ["Discharge at 0.3C until 2.5 V (5 minute period)"],
)

# Run the simulation
sim_k = pybamm.Simulation(model, parameter_values=param, experiment=exp_k, var_pts=var_pts)
sol_k = sim_k.solve()

# Extract LLI loss (unit: A.h) and calculate the remaining capacity
Q_LLI_final_k = sol_k["Total lithium lost [mol]"].entries[-1] * 96485.3 / 3600
remaining_capacity_k = (5 - Q_LLI_final_k) / 5 * 100

print(f"When k={target_cycle}, the remaining capacity is: {remaining_capacity_k:.2f}%")
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Calculating cycle 1400 ...
# At t = 525.311 and h = 5.34397e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 511.208 and h = 5.205e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 498.232 and h = 1.00504e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 486.161 and h = 3.1181e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 258.604 and h = 1.3429e-08, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 377.359 and h = 9.53558e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 538.894 and h = 1.01789e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 534.931 and h = 4.25063e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 531.105 and h = 4.72857e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 527.406 and h = 4.18354e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 523.816 and h = 4.72589e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 520.319 and h = 3.26699e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 516.901 and h = 5.53416e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 513.557 and h = 6.52304e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 510.272 and h = 5.21645e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 507.038 and h = 9.72883e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 503.844 and h = 5.02582e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 500.68 and h = 5.41797e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 497.539 and h = 3.04724e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 494.415 and h = 6.04155e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 491.286 and h = 1.09861e-13, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 488.203 and h = 2.18769e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 485.1 and h = 1.84869e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 481.988 and h = 6.11981e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 478.857 and h = 8.50368e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 475.698 and h = 4.68605e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 472.498 and h = 2.54171e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 469.254 and h = 2.21563e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 259.677 and h = 1.33426e-08, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 462.6 and h = 4.82026e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 437.544 and h = 2.10987e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 339.542 and h = 8.09716e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 528.462 and h = 1.06212e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 302.222 and h = 8.02925e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 176.361 and h = 1.88421e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 176.353 and h = 1.88514e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 381.538 and h = 2.97029e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 341.801 and h = 7.42937e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 539.129 and h = 3.67132e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 537.066 and h = 3.02504e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 535.001 and h = 4.53881e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 532.937 and h = 1.71454e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 530.843 and h = 7.57492e-13, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 528.789 and h = 3.24822e-13, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 526.73 and h = 6.75609e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 524.639 and h = 2.94816e-13, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 522.569 and h = 3.30821e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 520.473 and h = 4.64394e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 518.365 and h = 3.90138e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 271.661 and h = 1.01574e-08, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 514.091 and h = 2.78782e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 228.75 and h = 1.20976e-08, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 228.744 and h = 9.02115e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 509.721 and h = 6.42922e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 507.514 and h = 6.83897e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 505.303 and h = 2.24123e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 503.089 and h = 6.14543e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 500.882 and h = 3.34898e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 498.685 and h = 5.24385e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 496.502 and h = 2.61012e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 494.338 and h = 4.59535e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 492.193 and h = 4.33486e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 490.068 and h = 3.58793e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 487.964 and h = 7.2892e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 485.883 and h = 3.81189e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 483.818 and h = 3.55499e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 481.766 and h = 1.69945e-10, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 479.732 and h = 3.51966e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 477.706 and h = 5.22079e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 475.687 and h = 4.92393e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 473.655 and h = 9.33357e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 471.665 and h = 4.35557e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 469.66 and h = 5.21874e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 467.659 and h = 2.48454e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 465.662 and h = 6.64217e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 463.671 and h = 1.54215e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 461.685 and h = 5.01072e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 459.708 and h = 5.96172e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 457.736 and h = 1.42012e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 455.774 and h = 4.29463e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 538.588 and h = 1.1838e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 515.802 and h = 4.92289e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 312.453 and h = 2.41536e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 402.043 and h = 9.79003e-10, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 352.946 and h = 1.42114e-08, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 389.779 and h = 8.04033e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 539.948 and h = 5.04143e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 538.389 and h = 2.29558e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 536.812 and h = 2.97062e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 535.215 and h = 3.63515e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 533.595 and h = 6.17456e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 531.954 and h = 5.90664e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 530.29 and h = 3.5036e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 528.594 and h = 4.61262e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 526.868 and h = 2.31193e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 525.104 and h = 3.07461e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 523.298 and h = 4.43313e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 521.46 and h = 1.37516e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 519.599 and h = 5.04979e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 517.732 and h = 4.0915e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 515.877 and h = 3.33253e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 514.048 and h = 4.35235e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 512.255 and h = 1.37835e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 510.5 and h = 2.57588e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 222.024 and h = 9.52124e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 222.025 and h = 9.52332e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 507.131 and h = 5.04067e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 505.523 and h = 2.00328e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 503.963 and h = 4.65155e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 218.887 and h = 4.7254e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 501 and h = 3.71203e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 499.595 and h = 2.34555e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 498.237 and h = 6.52873e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 496.924 and h = 2.54007e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 495.649 and h = 1.71083e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 494.403 and h = 4.92743e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 493.186 and h = 2.24655e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 491.987 and h = 3.20766e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 490.806 and h = 1.61895e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 489.636 and h = 2.20998e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 488.463 and h = 6.61353e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 487.329 and h = 7.12898e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 486.185 and h = 3.7207e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 485.039 and h = 4.46292e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 483.89 and h = 3.64498e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 482.735 and h = 5.94159e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 481.566 and h = 7.27126e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 480.368 and h = 1.7708e-13, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 479.175 and h = 5.13829e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 477.929 and h = 5.73341e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 476.639 and h = 4.16406e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 475.274 and h = 3.25263e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 473.804 and h = 2.74653e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 472.208 and h = 2.98521e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 470.463 and h = 3.7725e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 468.562 and h = 2.56041e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 466.517 and h = 4.15222e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 464.374 and h = 3.17184e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 462.2 and h = 1.21058e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 460.061 and h = 2.11423e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 458.006 and h = 4.72878e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 456.041 and h = 4.31305e-13, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 454.226 and h = 3.3898e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 530.394 and h = 2.01293e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 539.027 and h = 3.26284e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 423.976 and h = 2.31486e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 363.566 and h = 6.24998e-10, the corrector convergence failed repeatedly or with |h| = hmin.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# At t = 292.267 and h = 2.74484e-17, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 291.052 and h = 1.31272e-07, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 482.67 and h = 4.41164e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 250.338 and h = 2.17318e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 250.338 and h = 2.32807e-13, the corrector convergence failed repeatedly or with |h| = hmin.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# At t = 538.594 and h = 8.73287e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# At t = 275.676 and h = 1.63141e-07, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 277.347 and h = 4.87936e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# At t = 240.707 and h = 3.20531e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 240.706 and h = 3.0221e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# At t = 204.557 and h = 1.3125e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 204.558 and h = 1.85438e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# At t = 409.714 and h = 8.77727e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# At t = 525.595 and h = 8.94281e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 486.402 and h = 6.12396e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 447.894 and h = 1.41122e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 297.067 and h = 2.89688e-13, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 297.07 and h = 3.91165e-13, the corrector convergence failed repeatedly or with |h| = hmin.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# At t = 263.89 and h = 3.85747e-13, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 263.889 and h = 2.06024e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# At t = 231.105 and h = 1.14475e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 231.105 and h = 1.35372e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 198.684 and h = 4.26658e-13, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 198.683 and h = 6.6352e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# The linesearch algorithm failed with too small a step.
# At t = 529.707 and h = 2.93873e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# The linesearch algorithm failed with too small a step.
# At t = 495.246 and h = 2.3603e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# The linesearch algorithm failed with too small a step.
# At t = 461.27 and h = 6.12328e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# At t = 509.837 and h = 1.94298e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 281.34 and h = 6.64957e-16, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 281.342 and h = 7.65399e-17, the corrector convergence failed repeatedly or with |h| = hmin.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# At t = 538.048 and h = 4.43035e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 251.548 and h = 5.57824e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 251.551 and h = 1.79763e-10, the corrector convergence failed repeatedly or with |h| = hmin.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# 2025-02-27 23:38:32.009 - [ERROR] callbacks.on_experiment_error(233): Simulation error: Maximum number of decreased steps occurred at t=22118351.589847054 (final SolverError: 'Error in Function::call for 'F' [IdasInterface] at .../casadi/core/function.cpp:1432:
# Error in Function::call for 'F' [IdasInterface] at .../casadi/core/function.cpp:361:
# .../casadi/interfaces/sundials/idas_interface.cpp:596: IDACalcIC returned "IDA_LINESEARCH_FAIL". Consult IDAS documentation.'). For a full solution try reducing dt_max (currently, dt_max=600) and/or reducing the size of the time steps or period of the experiment. Set `return_solution_if_failed_early=True` to return the solution object up to the point where failure occured.
# When k=1400, the remaining capacity is: 78.71%
