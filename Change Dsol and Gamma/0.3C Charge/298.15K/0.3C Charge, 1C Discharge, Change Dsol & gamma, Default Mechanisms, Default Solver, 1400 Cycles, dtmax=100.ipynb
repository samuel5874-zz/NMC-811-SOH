# %%
# Install necessary libraries
# %pip install "pybamm[plot,cite]" -q

import pybamm
import matplotlib.pyplot as plt

# Define the battery model
model = pybamm.lithium_ion.DFN(
    {
        "SEI": "solvent-diffusion limited",
        "SEI porosity change": "true",
        "lithium plating": "partially reversible",
        "lithium plating porosity change": "true",  # alias for "SEI porosity change"
        "particle mechanics": ("swelling and cracking", "swelling only"),
        "SEI on cracks": "true",
        "loss of active material": "stress-driven",
        "calculate discharge energy": "true",  # for compatibility with older PyBaMM versions
    }
)

# Set model parameters
param = pybamm.ParameterValues("OKane2022")
param.update({
    "SEI solvent diffusivity [m2.s-1]": 2e-21,  # The new value can be adjusted as needed
    'Dead lithium decay constant [s-1]': 7.5e-5,
})

var_pts = {
    "x_n": 5,  # Negative electrode
    "x_s": 5,  # Separator
    "x_p": 5,  # Positive electrode
    "r_n": 30,  # Negative electrode particles
    "r_p": 30,  # Positive electrode particles
}

# Set the target number of cycles
target_cycle = 1400

print(f"Calculating cycle {target_cycle} ...")

# Define the experimental protocol
exp_k = pybamm.Experiment(
    [
        "Hold at 4.2 V until C/100 (5 minute period)",
        "Rest for 4 hours (5 minute period)",
        "Discharge at 0.1C until 2.5 V (5 minute period)",
        "Charge at 0.3C until 4.2 V (5 minute period)",
        "Hold at 4.2 V until C/100 (5 minute period)",
    ]
    + [
        (
            "Discharge at 1C until 2.5 V",
            "Charge at 0.3C until 4.2 V (5 minute period)",
            "Hold at 4.2 V until C/100 (5 minute period)",
        )
    ]
    * target_cycle
    + ["Discharge at 0.1C until 2.5 V (5 minute period)"],
)
# Create solver with a smaller dt_max
solver = pybamm.CasadiSolver(dt_max=100)  # Try reducing further, e.g., dt_max=50 or 10 if needed
print(f"Current dt_max: {solver.dt_max}")

# Run the simulation
sim_k = pybamm.Simulation(model, parameter_values=param, experiment=exp_k, var_pts=var_pts, solver=solver)
sol_k = sim_k.solve()

# Extract LLI loss (unit: A.h) and calculate the remaining capacity
Q_LLI_final_k = sol_k["Total lithium lost [mol]"].entries[-1] * 96485.3 / 3600
remaining_capacity_k = (5 - Q_LLI_final_k) / 5 * 100

print(f"When k={target_cycle}, the remaining capacity is: {remaining_capacity_k:.2f}%")
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Calculating cycle 1400 ...
# Current dt_max: 100
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# At t = 265.618 and h = 6.03336e-13, the corrector convergence failed repeatedly or with |h| = hmin.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# At t = 275.274 and h = 1.89577e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# At t = 242.272 and h = 9.4333e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# At t = 296.372 and h = 3.08415e-16, the corrector convergence failed repeatedly or with |h| = hmin.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# At t = 267.594 and h = 4.94228e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# At t = 239.207 and h = 1.32444e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# At t = 211.208 and h = 1.00139e-16, the corrector convergence failed repeatedly or with |h| = hmin.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# At t = 298.951 and h = 9.0698e-17, the corrector convergence failed repeatedly or with |h| = hmin.
# The linesearch algorithm failed with too small a step.
# At t = 273.783 and h = 4.47984e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 248.295 and h = 1.09674e-07, the corrector convergence failed repeatedly or with |h| = hmin.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# At t = 224.274 and h = 2.88909e-16, the corrector convergence failed repeatedly or with |h| = hmin.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# At t = 199.92 and h = 3.80132e-13, the corrector convergence failed repeatedly or with |h| = hmin.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# 2025-02-26 20:04:09.017 - [ERROR] callbacks.on_experiment_error(233): Simulation error: Maximum number of decreased steps occurred at t=19084528.58965111 (final SolverError: 'Error in Function::call for 'F' [IdasInterface] at .../casadi/core/function.cpp:1432:
# Error in Function::call for 'F' [IdasInterface] at .../casadi/core/function.cpp:361:
# .../casadi/interfaces/sundials/idas_interface.cpp:596: IDACalcIC returned "IDA_LINESEARCH_FAIL". Consult IDAS documentation.'). For a full solution try reducing dt_max (currently, dt_max=100) and/or reducing the size of the time steps or period of the experiment. Set `return_solution_if_failed_early=True` to return the solution object up to the point where failure occured.
# When k=1400, the remaining capacity is: 76.76%
