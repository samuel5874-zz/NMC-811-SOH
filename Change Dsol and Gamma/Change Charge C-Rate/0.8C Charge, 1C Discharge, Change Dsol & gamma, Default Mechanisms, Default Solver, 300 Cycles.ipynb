# %%
# Install necessary libraries
# %pip install "pybamm[plot,cite]" -q

import pybamm
import matplotlib.pyplot as plt

# Define the battery model
model = pybamm.lithium_ion.DFN(
    {
        "SEI": "solvent-diffusion limited",
        "SEI porosity change": "true",
        "lithium plating": "partially reversible",
        "lithium plating porosity change": "true",  # alias for "SEI porosity change"
        "particle mechanics": ("swelling and cracking", "swelling only"),
        "SEI on cracks": "true",
        "loss of active material": "stress-driven",
        "calculate discharge energy": "true",  # for compatibility with older PyBaMM versions
    }
)

# Set model parameters
param = pybamm.ParameterValues("OKane2022")
param.update({
    "SEI solvent diffusivity [m2.s-1]": 2e-21,  # The new value can be adjusted as needed
    'Dead lithium decay constant [s-1]': 7.5e-5,
})

var_pts = {
    "x_n": 5,  # Negative electrode
    "x_s": 5,  # Separator
    "x_p": 5,  # Positive electrode
    "r_n": 30,  # Negative electrode particles
    "r_p": 30,  # Positive electrode particles
}

# Set the target number of cycles
target_cycle = 300

print(f"Calculating cycle {target_cycle} ...")

# Define the experimental protocol
exp_k = pybamm.Experiment(
    [
        "Hold at 4.2 V until C/100 (5 minute period)",
        "Rest for 4 hours (5 minute period)",
        "Discharge at 0.1C until 2.5 V (5 minute period)",
        "Charge at 0.3C until 4.2 V (5 minute period)",
        "Hold at 4.2 V until C/100 (5 minute period)",
    ]
    + [
        (
            "Discharge at 1C until 2.5 V",
            "Charge at 0.8C until 4.2 V (5 minute period)",
            "Hold at 4.2 V until C/100 (5 minute period)",
        )
    ]
    * target_cycle
    + ["Discharge at 0.1C until 2.5 V (5 minute period)"],
)

# Run the simulation
sim_k = pybamm.Simulation(model, parameter_values=param, experiment=exp_k, var_pts=var_pts)
sol_k = sim_k.solve()

# Extract LLI loss (unit: A.h) and calculate the remaining capacity
Q_LLI_final_k = sol_k["Total lithium lost [mol]"].entries[-1] * 96485.3 / 3600
remaining_capacity_k = (5 - Q_LLI_final_k) / 5 * 100

print(f"When k={target_cycle}, the remaining capacity is: {remaining_capacity_k:.2f}%")
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Calculating cycle 300 ...
# At t = 469.698 and h = 9.84043e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 229.698 and h = 1.18976e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 310.736 and h = 6.27546e-10, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 164.805 and h = 3.79499e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 399.998 and h = 1.52984e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 159.998 and h = 9.53332e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 395.281 and h = 9.60638e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 390.837 and h = 4.54904e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 386.722 and h = 1.1537e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 382.915 and h = 6.67968e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 379.332 and h = 6.30353e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 375.879 and h = 9.36486e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 372.503 and h = 6.76299e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 369.111 and h = 1.01989e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 365.622 and h = 5.06086e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 302.975 and h = 1.73132e-10, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 358.229 and h = 6.98935e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 355.124 and h = 5.72811e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 352.241 and h = 1.64698e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 349.44 and h = 4.20746e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 346.657 and h = 1.8593e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 343.867 and h = 1.01632e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 341.05 and h = 1.6233e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 338.153 and h = 3.77821e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 334.967 and h = 3.05141e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 331.673 and h = 7.34009e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 328.776 and h = 9.07538e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 326.176 and h = 1.21202e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 323.735 and h = 2.65268e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 321.418 and h = 1.25239e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 319.175 and h = 1.00569e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 239.999 and h = 2.09664e-10, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 316.983 and h = 1.58781e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 314.822 and h = 1.53225e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 203.236 and h = 3.47266e-10, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 310.501 and h = 3.82761e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 308.28 and h = 5.14722e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 210.917 and h = 7.19613e-10, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 210.932 and h = 7.18859e-10, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 303.46 and h = 9.03254e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 300.824 and h = 5.12309e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 298.306 and h = 1.34003e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 296.016 and h = 1.14861e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 293.875 and h = 7.7485e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 291.821 and h = 1.19934e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 289.821 and h = 1.42439e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 287.867 and h = 7.58743e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 202.436 and h = 1.9657e-10, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 285.935, repeated recoverable residual errors.
# At t = 284.026 and h = 2.99601e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 282.132 and h = 3.28117e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 280.258 and h = 6.37796e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 278.379 and h = 4.41738e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 276.472 and h = 3.52383e-13, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 274.49 and h = 5.38388e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 272.409 and h = 1.62747e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 270.29 and h = 3.39297e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 268.227 and h = 8.11286e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 266.266 and h = 7.11251e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 264.397 and h = 1.63857e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 262.592 and h = 3.14544e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 260.83 and h = 1.47472e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 259.096 and h = 3.69648e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 257.394 and h = 5.19294e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 255.706 and h = 2.79678e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 254.031 and h = 6.47937e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 167.759 and h = 7.42026e-10, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 252.368 and h = 4.29997e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 250.719 and h = 9.85121e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 249.082 and h = 4.57795e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 247.454 and h = 1.25809e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 245.828 and h = 6.84765e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 160.555 and h = 1.04293e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 160.552 and h = 1.03836e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 242.53 and h = 1.37453e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 240.862 and h = 1.19665e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 239.22 and h = 1.1059e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 239.219 and h = 2.16258e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 237.621 and h = 4.80983e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 140.572 and h = 5.4574e-10, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 236.078 and h = 4.33191e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 236.078 and h = 3.15757e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 234.585 and h = 1.52638e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 234.589 and h = 6.88638e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 233.146 and h = 4.74878e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 233.146 and h = 1.04259e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 231.731 and h = 1.33116e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 145.916 and h = 3.52846e-10, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 230.332 and h = 7.0851e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 230.332 and h = 4.54527e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 228.934 and h = 1.91717e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 228.934 and h = 2.14565e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 227.52 and h = 6.47926e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 227.52 and h = 1.45858e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 226.081 and h = 1.03973e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 226.077 and h = 2.67223e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 224.617 and h = 1.05771e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 224.617 and h = 3.2165e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 148.834 and h = 7.38913e-10, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 223.128 and h = 1.08179e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 221.62 and h = 1.4635e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 221.62 and h = 5.32779e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 220.103 and h = 8.49921e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 220.103 and h = 2.38531e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 218.577 and h = 1.63518e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 218.578 and h = 9.37697e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 217.038 and h = 1.50648e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 217.038 and h = 5.07158e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 215.475 and h = 1.16881e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 215.475 and h = 8.79187e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 213.899 and h = 5.05343e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 213.899 and h = 5.85857e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 212.336 and h = 4.3102e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 212.336 and h = 1.04235e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 210.809 and h = 3.77554e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 210.809 and h = 1.81595e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 209.328 and h = 5.6642e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 209.328 and h = 6.96845e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 207.895 and h = 5.06972e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 207.895 and h = 8.00514e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 206.499 and h = 1.00421e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 206.499 and h = 4.85011e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 205.127 and h = 1.42717e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 205.127 and h = 5.08991e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 203.775 and h = 1.17485e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 203.775 and h = 7.92639e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 202.438 and h = 1.12806e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 202.438 and h = 1.03936e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 201.115 and h = 1.31866e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 201.115 and h = 8.89151e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 199.802 and h = 4.93736e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 199.802 and h = 3.97152e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 198.496 and h = 1.26699e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 198.497 and h = 6.79883e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 197.194 and h = 5.66077e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 197.194 and h = 1.01165e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 195.889 and h = 2.85916e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 195.893 and h = 1.61641e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 194.591 and h = 3.45978e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 194.591 and h = 1.62144e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 193.29 and h = 9.38673e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 193.29 and h = 1.06786e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 191.987 and h = 1.69441e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 99.35 and h = 5.80346e-10, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 190.681 and h = 6.61606e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 190.676 and h = 2.99312e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 189.373, repeated recoverable residual errors.
# At t = 189.372 and h = 9.29279e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 188.064 and h = 9.19655e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 188.064 and h = 4.03882e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 186.758 and h = 2.64644e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 186.758 and h = 5.52062e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 185.459 and h = 1.26593e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 185.459 and h = 3.80952e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 184.17 and h = 3.49857e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 184.17 and h = 4.96549e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 182.896 and h = 1.06993e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 182.896 and h = 3.7752e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 181.639 and h = 1.85052e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 181.639 and h = 6.25982e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 180.402 and h = 8.57016e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 180.402 and h = 1.75676e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 179.185 and h = 7.65536e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 179.185 and h = 8.42706e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 90.853 and h = 8.42359e-10, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 177.986 and h = 7.95153e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 176.803 and h = 3.40979e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 176.803 and h = 9.39096e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 175.635 and h = 1.23149e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 175.635 and h = 1.0473e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 174.48 and h = 3.22238e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 174.48 and h = 4.66875e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 173.333 and h = 8.4464e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 173.333 and h = 9.7789e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 172.19 and h = 4.26235e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 172.19 and h = 1.15267e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 171.047 and h = 1.50722e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 171.048 and h = 1.10133e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 169.899 and h = 5.9907e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 169.899 and h = 5.18571e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 168.739 and h = 7.70131e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 168.739 and h = 3.22125e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 167.571 and h = 5.0848e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 167.57 and h = 1.22681e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 166.397 and h = 3.87125e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 131.467 and h = 9.90819e-10, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 165.223 and h = 1.52237e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 165.223 and h = 8.69533e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 164.052 and h = 7.14744e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 164.052 and h = 1.16318e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 162.886 and h = 1.01453e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 162.886 and h = 1.86736e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 161.729 and h = 8.08733e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 161.729 and h = 6.00976e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 160.582 and h = 8.16674e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 160.582 and h = 1.14182e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 159.446 and h = 7.30374e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 75.8933 and h = 8.68254e-10, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 75.8763 and h = 8.70707e-10, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 158.322 and h = 1.01307e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 158.322 and h = 8.36621e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 494.168 and h = 7.29609e-10, the corrector convergence failed repeatedly or with |h| = hmin.
# When k=300, the remaining capacity is: 87.72%
