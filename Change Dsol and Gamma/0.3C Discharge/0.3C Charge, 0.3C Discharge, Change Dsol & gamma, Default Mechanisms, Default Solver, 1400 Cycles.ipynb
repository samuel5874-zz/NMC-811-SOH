# %%
# Install necessary libraries
# %pip install "pybamm[plot,cite]" -q

import pybamm
import matplotlib.pyplot as plt

# Define the battery model
model = pybamm.lithium_ion.DFN(
    {
        "SEI": "solvent-diffusion limited",
        "SEI porosity change": "true",
        "lithium plating": "partially reversible",
        "lithium plating porosity change": "true",  # alias for "SEI porosity change"
        "particle mechanics": ("swelling and cracking", "swelling only"),
        "SEI on cracks": "true",
        "loss of active material": "stress-driven",
        "calculate discharge energy": "true",  # for compatibility with older PyBaMM versions
    }
)

# Set model parameters
param = pybamm.ParameterValues("OKane2022")
param.update({
    "SEI solvent diffusivity [m2.s-1]": 2e-21,  # The new value can be adjusted as needed
    'Dead lithium decay constant [s-1]': 7.5e-5,
})

var_pts = {
    "x_n": 5,  # Negative electrode
    "x_s": 5,  # Separator
    "x_p": 5,  # Positive electrode
    "r_n": 30,  # Negative electrode particles
    "r_p": 30,  # Positive electrode particles
}

# Set the target number of cycles
target_cycle = 1400

print(f"Calculating cycle {target_cycle} ...")

# Define the experimental protocol
exp_k = pybamm.Experiment(
    [
        "Hold at 4.2 V until C/100 (5 minute period)",
        "Rest for 4 hours (5 minute period)",
        "Discharge at 0.1C until 2.5 V (5 minute period)",
        "Charge at 0.3C until 4.2 V (5 minute period)",
        "Hold at 4.2 V until C/100 (5 minute period)",
    ]
    + [
        (
            "Discharge at 0.3C until 2.5 V",
            "Charge at 0.3C until 4.2 V (5 minute period)",
            "Hold at 4.2 V until C/100 (5 minute period)",
        )
    ]
    * target_cycle
    + ["Discharge at 0.1C until 2.5 V (5 minute period)"],
)

# Run the simulation
sim_k = pybamm.Simulation(model, parameter_values=param, experiment=exp_k, var_pts=var_pts)
sol_k = sim_k.solve()

# Extract LLI loss (unit: A.h) and calculate the remaining capacity
Q_LLI_final_k = sol_k["Total lithium lost [mol]"].entries[-1] * 96485.3 / 3600
remaining_capacity_k = (5 - Q_LLI_final_k) / 5 * 100

print(f"When k={target_cycle}, the remaining capacity is: {remaining_capacity_k:.2f}%")
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Calculating cycle 1400 ...
# At t = 531.303 and h = 4.06979e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 516.599 and h = 4.14321e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 503.179 and h = 3.48846e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 490.74 and h = 2.31599e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 479.087 and h = 5.10971e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 466.426 and h = 9.67846e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 470.569 and h = 8.70589e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 290.44 and h = 4.38819e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 535.976 and h = 8.94233e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 532.11 and h = 6.60055e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 528.375 and h = 4.73654e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 524.755 and h = 3.15402e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 521.228 and h = 7.06428e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 517.786 and h = 5.16961e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 514.422 and h = 2.7055e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 511.119 and h = 3.63468e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 507.871 and h = 1.87328e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 504.662 and h = 5.82527e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 501.488 and h = 2.60384e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 498.321 and h = 4.29732e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 495.207 and h = 4.44425e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 492.091 and h = 4.13163e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 488.982 and h = 9.96761e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 485.879 and h = 4.53589e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 482.768 and h = 4.29125e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 479.643 and h = 2.56888e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 476.488 and h = 3.33226e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 473.296 and h = 2.41756e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 470.06 and h = 7.26624e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 466.778 and h = 2.44859e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 463.435 and h = 5.8849e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 459.414 and h = 2.38147e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 441.223 and h = 6.98727e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 367.717 and h = 1.40591e-08, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 318.236 and h = 2.84174e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 539.457 and h = 3.53851e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 537.395 and h = 3.41846e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 535.331 and h = 6.44167e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 533.268 and h = 5.5188e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 531.202 and h = 2.22523e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 529.135 and h = 2.88093e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 527.063 and h = 5.60069e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 524.987 and h = 3.61099e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 522.903 and h = 3.18068e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 520.808 and h = 7.14699e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 518.702 and h = 5.8046e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 516.579 and h = 5.13636e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 514.432 and h = 5.95473e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 512.261 and h = 3.62216e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 510.068 and h = 2.96701e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 507.86 and h = 4.69711e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 505.647 and h = 2.48493e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 503.432 and h = 6.67549e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 501.221 and h = 7.29222e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 499.021 and h = 6.02479e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 496.835 and h = 4.28497e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 494.666 and h = 1.70941e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 492.517 and h = 1.57169e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 490.386 and h = 7.05296e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 488.28 and h = 6.88474e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 486.192 and h = 7.2049e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 484.127 and h = 2.01033e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 482.074 and h = 5.86485e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 480.035 and h = 1.57059e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 478.007 and h = 3.59511e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 475.987 and h = 8.02132e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 473.974 and h = 2.95186e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 471.966 and h = 1.62988e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 469.959 and h = 4.01526e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 467.957 and h = 1.27165e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 465.96 and h = 3.63411e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 463.968 and h = 5.33822e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 461.981 and h = 4.09062e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 460.002 and h = 4.81495e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 458.029 and h = 4.83021e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 456.067 and h = 1.13954e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 539.946 and h = 2.88359e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 533.781 and h = 5.21306e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 472.26 and h = 9.50714e-10, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 366.576 and h = 3.37336e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 511.962 and h = 3.58018e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 444.702 and h = 3.53452e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 538.634 and h = 2.915e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 537.06 and h = 5.07099e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 535.466 and h = 3.37193e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 533.851 and h = 3.91258e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 532.213 and h = 3.64962e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 530.552 and h = 3.03032e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 528.862 and h = 2.84284e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 527.141 and h = 3.96685e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 525.385 and h = 5.39016e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 523.591 and h = 1.40398e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 521.757 and h = 3.8277e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 519.901 and h = 4.28013e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 518.036 and h = 3.38708e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 516.164 and h = 7.53428e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 514.34 and h = 2.88603e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 512.536 and h = 2.99831e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 510.771 and h = 3.40941e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 509.048 and h = 4.08682e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 507.375 and h = 3.97436e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 505.752 and h = 3.54983e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 504.179 and h = 2.75005e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 502.656 and h = 8.75688e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 219.839 and h = 4.7003e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 501.187 and h = 1.64157e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 499.768 and h = 1.75243e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 498.397 and h = 5.34682e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 497.073 and h = 3.88636e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 495.786 and h = 2.7458e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 494.534 and h = 1.8931e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 493.308 and h = 4.31252e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 492.104 and h = 5.82613e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 490.919 and h = 2.88149e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 489.747 and h = 3.1049e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 488.588 and h = 3.7063e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 487.438 and h = 4.25762e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 486.293 and h = 4.57945e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 485.148 and h = 4.5572e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 484.001 and h = 6.68986e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 482.85 and h = 3.68031e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 481.689 and h = 4.6304e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 480.512 and h = 3.76809e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 479.312 and h = 2.99074e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 478.077 and h = 5.56891e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 476.805 and h = 4.43645e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 475.466 and h = 3.54492e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 474.031 and h = 2.75668e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 472.475 and h = 3.77803e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 470.779 and h = 3.99142e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 468.926 and h = 7.02091e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 466.926 and h = 2.12513e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 464.811 and h = 4.95338e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 462.641 and h = 5.81243e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 460.49 and h = 5.95948e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 458.41 and h = 7.08137e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 456.428 and h = 2.23501e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 454.558 and h = 6.38832e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 504.082 and h = 7.50516e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 484.424 and h = 3.46883e-09, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 456.306 and h = 3.46702e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 298.741 and h = 1.59297e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 298.74 and h = 4.2749e-13, the corrector convergence failed repeatedly or with |h| = hmin.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# At t = 512.866 and h = 7.52372e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 273.42 and h = 8.4882e-16, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 273.421 and h = 7.76691e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# At t = 459.525 and h = 1.91654e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 231.972 and h = 3.31419e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 231.972 and h = 2.88923e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# At t = 519.254 and h = 1.12756e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# At t = 298.382 and h = 3.92951e-16, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 298.383 and h = 1.72724e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# At t = 261.527 and h = 2.05474e-13, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 261.524 and h = 3.43918e-13, the corrector convergence failed repeatedly or with |h| = hmin.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# At t = 225.164 and h = 9.65738e-16, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 225.163 and h = 7.01703e-16, the corrector convergence failed repeatedly or with |h| = hmin.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# At t = 488.622 and h = 3.56109e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# At t = 509.064 and h = 3.5898e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 470.245 and h = 4.28266e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 283.342 and h = 3.64885e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 283.342 and h = 9.48788e-13, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 250.398 and h = 1.50774e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 250.399 and h = 1.00443e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 217.846 and h = 8.30316e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 215.82 and h = 1.23269e-07, the corrector convergence failed repeatedly or with |h| = hmin.
# The linesearch algorithm failed with too small a step.
# At t = 185.638 and h = 3.30289e-13, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 185.637 and h = 3.7455e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# The linesearch algorithm failed with too small a step.
# At t = 515.761 and h = 2.34712e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# The linesearch algorithm failed with too small a step.
# At t = 481.567 and h = 1.90031e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# The linesearch algorithm failed with too small a step.
# At t = 447.858 and h = 6.25833e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# At t = 299.611 and h = 1.07496e-13, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 299.613 and h = 2.1022e-16, the corrector convergence failed repeatedly or with |h| = hmin.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# At t = 497.399 and h = 6.01139e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 269.716 and h = 3.62608e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 268.7 and h = 5.81627e-08, the corrector convergence failed repeatedly or with |h| = hmin.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# At t = 465.825 and h = 5.98518e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 240.137 and h = 8.31164e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 240.137 and h = 2.17881e-13, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 494.645 and h = 1.45075e-11, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 210.85 and h = 5.37797e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 210.851 and h = 1.38994e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# The linesearch algorithm failed with too small a step.
# 2025-02-26 18:56:53.580 - [ERROR] callbacks.on_experiment_error(233): Simulation error: Maximum number of decreased steps occurred at t=22179236.553767618 (final SolverError: 'Error in Function::call for 'F' [IdasInterface] at .../casadi/core/function.cpp:1432:
# Error in Function::call for 'F' [IdasInterface] at .../casadi/core/function.cpp:361:
# .../casadi/interfaces/sundials/idas_interface.cpp:596: IDACalcIC returned "IDA_LINESEARCH_FAIL". Consult IDAS documentation.'). For a full solution try reducing dt_max (currently, dt_max=600) and/or reducing the size of the time steps or period of the experiment. Set `return_solution_if_failed_early=True` to return the solution object up to the point where failure occured.
# When k=1400, the remaining capacity is: 78.69%
